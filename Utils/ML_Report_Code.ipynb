# %%
import pandas as pd
import mplfinance as mpf
import warnings

# Ignorar todos los warnings
warnings.filterwarnings("ignore")

df = pd.read_csv('../data/aapl_1d_train.csv')
df
# Out:
#             Date      Open      High       Low     Close  Adjusted_close  \
# 0     2000-01-03  104.8768  112.5040  101.6848  111.9328          0.8472
# 1     2000-01-04  108.2480  110.6224  101.1920  102.5024          0.7758
# 2     2000-01-05  103.7456  110.5664  102.9952  104.0032          0.7872
# 3     2000-01-06  106.1200  107.0048   94.9984   94.9984          0.7190
# 4     2000-01-07   96.4992  101.0016   95.5024   99.5008          0.7531
# ...          ...       ...       ...       ...       ...             ...
# 5279  2020-12-24  131.3200  133.4600  131.1000  131.9700        129.6797
# 5280  2020-12-28  133.9900  137.3400  133.5100  136.6900        134.3178
# 5281  2020-12-29  138.0500  138.7900  134.3400  134.8700        132.5294
# 5282  2020-12-30  135.5800  135.9900  133.4000  133.7200        131.3994
# 5283  2020-12-31  134.0800  134.7400  131.7200  132.6900        130.3872
#
#          Volume
# 0     535796800
# 1     512377600
# 2     778321600
# 3     767972800
# 4     460734400
# ...         ...
# 5279   54930100
# 5280  124486200
# 5281  121047300
# 5282   96452100
# 5283   99116600
#
# [5284 rows x 7 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# Crear el gráfico de velas
mpf.plot(df, type='candle', style='charles', title='Candlestick Chart', ylabel='Price')

# %%
from
