# %%
import pandas as pd
import ta 
import optuna 
import time
import numpy as np
from multiprocessing import Pool
from itertools import combinations, chain 
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
def powerset(s):
    return chain.from_iterable(combinations(s,r) for r in range(1,len(s)+1))

# %%
def file_features(data, ds_type: str):
    data1=pd.DataFrame()
    #Calcular indicadores tecnicos
    cmf_data = ta.volume.ChaikinMoneyFlowIndicator(data.High, data.Low, data.Close, data.Volume, window = 14)
    rsi_data = ta.momentum.RSIIndicator(data.Close, window=14)
    
    data1["CMF"] = cmf_data.chaikin_money_flow()
    data1["RSI"] = rsi_data.rsi()
    # Calcular la volatilidad
    data1['Volatility'] = data['High'] - data['Low']
    data1['Close_Lag0'] = data['Close']
    # Calcular las tendencias
    for i in range(1, 5 + 1):
        data1[f'Close_Lag{i}'] = data['Close'].shift(i)
    #Variable ded respuesta
    if ds_type == "buy":
        data1['Response'] = (data['Close'] < data['Close'].shift(-10))
    else:
        data1['Response'] = (data['Close'] > data['Close'].shift(-10))
    
    data1 = data1.drop(data1.index[:30])
    data1 = data1.drop(data1.index[-30:])
    data1.reset_index(drop=True, inplace=True)
    
    return data1

# %%
def objective_log_regresor(trial, data):
    # Dividir los datos en conjuntos de entrenamiento y prueba
    X = data.iloc[:, :-1]
    # Selecciona la variable objetivo
    y = data.iloc[:, -1]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
    
    # Definir los parámetros a optimizar
    penalty = trial.suggest_categorical('penalty', ['l1', 'l2'])
    C = trial.suggest_loguniform('C', 0.001, 1000)
    solver = trial.suggest_categorical('solver', ['liblinear', 'saga'])

    # Crear el modelo de regresión logística con los parámetros sugeridos
    model = LogisticRegression(penalty=penalty, C=C, solver=solver, max_iter=10_000, random_state=123)
    # Entrenar el modelo
    model.fit(X_train, y_train)
    # Calcular la precisión en el conjunto de prueba
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy

# %%
def objective_svm(trial, data):
    # Dividir los datos en conjuntos de entrenamiento y prueba
    X = data.iloc[:, :-1]
    # Selecciona la variable objetivo
    y = data.iloc[:, -1]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

    # Definir los parámetros a optimizar
    C = trial.suggest_loguniform('C', 0.001, 1000)
    kernel = trial.suggest_categorical('kernel', ['linear', 'poly', 'rbf', 'sigmoid'])
    if kernel == 'poly':
        degree = trial.suggest_int('degree', 2, 5)
    else:
        degree = 3  # Valor predeterminado si el kernel no es 'poly'
    gamma = trial.suggest_categorical('gamma', ['scale', 'auto']) if kernel in ['rbf', 'poly', 'sigmoid'] else 'scale'
    # Crear el modelo SVM con los parámetros sugeridos
    model = SVC(C=C, kernel=kernel, degree=degree, gamma=gamma, max_iter=100_000, random_state=123)
    # Entrenar el modelo
    model.fit(X_train, y_train)
    # Calcular la precisión en el conjunto de prueba
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy

# %%
def objective_xgboost(trial, data):
    data = data.copy()
    # Dividir los datos en conjuntos de entrenamiento y prueba
    X = data.iloc[:, :-1]
    # Selecciona la variable objetivo
    y = data.iloc[:, -1]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
    # Definir los parámetros a optimizar
    n_estimators = trial.suggest_int('n_estimators', 100, 1000, step=100)
    max_depth = trial.suggest_int('max_depth', 3, 10)
    learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
    subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
    colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
    # Crear el modelo XGBoost con los parámetros sugeridos
    model = XGBClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        learning_rate=learning_rate,
        subsample=subsample,
        colsample_bytree=colsample_bytree,
        random_state=123
    )
    # Entrenar el modelo
    model.fit(X_train, y_train)
    # Calcular la precisión en el conjunto de prueba
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy

# %%
def optimize_params_log_regresor(data):
    # Crear un estudio Optuna para la optimización
    study = optuna.create_study(direction='maximize')
    
    # Función objetivo con el dataset como parámetro fijo
    objective_fn = lambda trial: objective_log_regresor(trial, data)
    
    # Ejecutar la optimización
    study.optimize(objective_fn, n_trials=25)

    # Obtener los mejores parámetros
    best_params = study.best_params
    best_accuracy = study.best_value

    return best_params, best_accuracy

# %%
def optimize_params_svm(data):
    # Crear un estudio Optuna para la optimización
    study = optuna.create_study(direction='maximize')
    
    # Función objetivo con el dataset como parámetro fijo
    objective_fn = lambda trial: objective_svm(trial, data)
    
    # Ejecutar la optimización
    study.optimize(objective_fn, n_trials=25)

    # Obtener los mejores parámetros
    best_params = study.best_params
    best_accuracy = study.best_value

    return best_params, best_accuracy

# %%
def optimize_params_xgboost(data):
    # Crear un estudio Optuna para la optimización
    study = optuna.create_study(direction='maximize')
    
    # Función objetivo con el dataset como parámetro fijo
    objective_fn = lambda trial: objective_xgboost(trial, data)
    
    # Ejecutar la optimización
    study.optimize(objective_fn, n_trials=25)

    # Obtener los mejores parámetros
    best_params = study.best_params
    best_accuracy = study.best_value

    return best_params, best_accuracy

# %%
def optimize_params(data):
    # Optimización de regresión logística
    best_params_lr, best_accuracy_lr = optimize_params_log_regresor(data)
    print("Mejores parámetros de regresión logística:", best_params_lr)
    print("Precisión del modelo de regresión logística:", best_accuracy_lr)
    # Optimización de SVM
    best_params_svm, best_accuracy_svm = optimize_params_svm(data)
    print("Mejores parámetros de SVM:", best_params_svm)
    print("Precisión del modelo de SVM:", best_accuracy_svm)
    # Optimización de XGBoost
    best_params_xgb, best_accuracy_xgb = optimize_params_xgboost(data)
    print("Mejores parámetros de XGBoost:", best_params_xgb)
    print("Precisión del modelo de XGBoost:", best_accuracy_xgb)

# %%
data_1d_train = pd.read_csv("data/aapl_1d_train.csv")
data_1d_train = data_1d_train.dropna()
dataresult_long_1d_train = file_features(data_1d_train, ds_type="buy")
dataresult_short_1d_train = file_features(data_1d_train, ds_type="sell")
params_1d_long = optimize_params(dataresult_long_1d_train)
params_1d_short = optimize_params(dataresult_short_1d_train)
# Out:
# [I 2024-03-25 18:37:03,395] A new study created in memory with name: no-name-1dc52719-1e91-4bf1-b296-5dff24d46387
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:06,608] Trial 0 finished with value: 0.6564593301435406 and parameters: {'penalty': 'l2', 'C': 0.10332382197428353, 'solver': 'saga'}. Best is trial 0 with value: 0.6564593301435406.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:07,920] Trial 1 finished with value: 0.6583732057416268 and parameters: {'penalty': 'l1', 'C': 994.9539555852161, 'solver': 'liblinear'}. Best is trial 1 with value: 0.6583732057416268.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:10,454] Trial 2 finished with value: 0.6555023923444976 and parameters: {'penalty': 'l2', 'C': 0.008409497311641048, 'solver': 'saga'}. Best is trial 1 with value: 0.6583732057416268.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:11,849] Trial 3 finished with value: 0.6593301435406699 and parameters: {'penalty': 'l1', 'C': 5.530574390820864, 'solver': 'liblinear'}. Best is trial 3 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:14,951] Trial 4 finished with value: 0.6555023923444976 and parameters: {'penalty': 'l2', 'C': 0.041324507682046166, 'solver': 'saga'}. Best is trial 3 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:14,964] Trial 5 finished with value: 0.6593301435406699 and parameters: {'penalty': 'l2', 'C': 0.5167405108601244, 'solver': 'liblinear'}. Best is trial 3 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:18,754] Trial 6 finished with value: 0.6564593301435406 and parameters: {'penalty': 'l1', 'C': 3.8607506839408425, 'solver': 'saga'}. Best is trial 3 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:19,993] Trial 7 finished with value: 0.6593301435406699 and parameters: {'penalty': 'l1', 'C': 0.29743072475924665, 'solver': 'liblinear'}. Best is trial 3 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:23,815] Trial 8 finished with value: 0.6564593301435406 and parameters: {'penalty': 'l1', 'C': 184.94723310727622, 'solver': 'saga'}. Best is trial 3 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:23,828] Trial 9 finished with value: 0.6593301435406699 and parameters: {'penalty': 'l2', 'C': 72.57558941616603, 'solver': 'liblinear'}. Best is trial 3 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:25,109] Trial 10 finished with value: 0.6593301435406699 and parameters: {'penalty': 'l1', 'C': 10.79648544245721, 'solver': 'liblinear'}. Best is trial 3 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:25,124] Trial 11 finished with value: 0.6583732057416268 and parameters: {'penalty': 'l2', 'C': 1.559449313794876, 'solver': 'liblinear'}. Best is trial 3 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:25,135] Trial 12 finished with value: 0.6593301435406699 and parameters: {'penalty': 'l1', 'C': 0.0010639447511717425, 'solver': 'liblinear'}. Best is trial 3 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:25,151] Trial 13 finished with value: 0.6593301435406699 and parameters: {'penalty': 'l2', 'C': 16.42287448981358, 'solver': 'liblinear'}. Best is trial 3 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:26,431] Trial 14 finished with value: 0.6593301435406699 and parameters: {'penalty': 'l1', 'C': 0.7643014617897705, 'solver': 'liblinear'}. Best is trial 3 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:26,444] Trial 15 finished with value: 0.6535885167464115 and parameters: {'penalty': 'l2', 'C': 0.03370056621639209, 'solver': 'liblinear'}. Best is trial 3 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:26,459] Trial 16 finished with value: 0.6593301435406699 and parameters: {'penalty': 'l2', 'C': 25.23264192305611, 'solver': 'liblinear'}. Best is trial 3 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:27,786] Trial 17 finished with value: 0.6593301435406699 and parameters: {'penalty': 'l1', 'C': 2.740069456910937, 'solver': 'liblinear'}. Best is trial 3 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:27,801] Trial 18 finished with value: 0.6593301435406699 and parameters: {'penalty': 'l2', 'C': 0.2923362779996846, 'solver': 'liblinear'}. Best is trial 3 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:29,361] Trial 19 finished with value: 0.6593301435406699 and parameters: {'penalty': 'l1', 'C': 0.45564633759074946, 'solver': 'liblinear'}. Best is trial 3 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:29,603] Trial 20 finished with value: 0.661244019138756 and parameters: {'penalty': 'l1', 'C': 0.006031005446696971, 'solver': 'liblinear'}. Best is trial 20 with value: 0.661244019138756.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:29,724] Trial 21 finished with value: 0.6631578947368421 and parameters: {'penalty': 'l1', 'C': 0.004230720669978713, 'solver': 'liblinear'}. Best is trial 21 with value: 0.6631578947368421.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:29,867] Trial 22 finished with value: 0.6631578947368421 and parameters: {'penalty': 'l1', 'C': 0.004580219778069443, 'solver': 'liblinear'}. Best is trial 21 with value: 0.6631578947368421.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:29,878] Trial 23 finished with value: 0.6593301435406699 and parameters: {'penalty': 'l1', 'C': 0.0012414487325493734, 'solver': 'liblinear'}. Best is trial 21 with value: 0.6631578947368421.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/583301789.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:30,100] Trial 24 finished with value: 0.662200956937799 and parameters: {'penalty': 'l1', 'C': 0.005679961070967571, 'solver': 'liblinear'}. Best is trial 21 with value: 0.6631578947368421.
# [I 2024-03-25 18:37:30,100] A new study created in memory with name: no-name-58842fdb-6580-46e4-b564-0f987fe8014a
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# Mejores parámetros de regresión logística: {'penalty': 'l1', 'C': 0.004230720669978713, 'solver': 'liblinear'}
# Precisión del modelo de regresión logística: 0.6631578947368421
# [I 2024-03-25 18:37:30,905] Trial 0 finished with value: 0.6593301435406699 and parameters: {'C': 0.19971754866060473, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 0 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:31,206] Trial 1 finished with value: 0.5578947368421052 and parameters: {'C': 19.90973059795461, 'kernel': 'sigmoid', 'gamma': 'scale'}. Best is trial 0 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:31,543] Trial 2 finished with value: 0.5578947368421052 and parameters: {'C': 0.20286289357931717, 'kernel': 'sigmoid', 'gamma': 'scale'}. Best is trial 0 with value: 0.6593301435406699.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# /opt/anaconda3/envs/trading/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [I 2024-03-25 18:37:32,534] Trial 3 finished with value: 0.661244019138756 and parameters: {'C': 0.010285159938351896, 'kernel': 'linear'}. Best is trial 3 with value: 0.661244019138756.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# /opt/anaconda3/envs/trading/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [I 2024-03-25 18:37:34,173] Trial 4 finished with value: 0.5100478468899522 and parameters: {'C': 10.055865135159104, 'kernel': 'linear'}. Best is trial 3 with value: 0.661244019138756.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:34,919] Trial 5 finished with value: 0.6593301435406699 and parameters: {'C': 0.002286200179602409, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 3 with value: 0.661244019138756.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# /opt/anaconda3/envs/trading/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [I 2024-03-25 18:37:35,782] Trial 6 finished with value: 0.6593301435406699 and parameters: {'C': 0.0014998227425154353, 'kernel': 'linear'}. Best is trial 3 with value: 0.661244019138756.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:36,283] Trial 7 finished with value: 0.6593301435406699 and parameters: {'C': 0.0703616317835488, 'kernel': 'poly', 'degree': 3, 'gamma': 'scale'}. Best is trial 3 with value: 0.661244019138756.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:37,053] Trial 8 finished with value: 0.6593301435406699 and parameters: {'C': 0.06285537677914275, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 3 with value: 0.661244019138756.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:37,444] Trial 9 finished with value: 0.6593301435406699 and parameters: {'C': 19.379207941480463, 'kernel': 'sigmoid', 'gamma': 'auto'}. Best is trial 3 with value: 0.661244019138756.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# /opt/anaconda3/envs/trading/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [I 2024-03-25 18:37:39,081] Trial 10 finished with value: 0.4478468899521531 and parameters: {'C': 724.8533189037172, 'kernel': 'linear'}. Best is trial 3 with value: 0.661244019138756.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:39,763] Trial 11 finished with value: 0.6593301435406699 and parameters: {'C': 0.012605010418650493, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 3 with value: 0.661244019138756.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# /opt/anaconda3/envs/trading/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [I 2024-03-25 18:37:41,601] Trial 12 finished with value: 0.6593301435406699 and parameters: {'C': 1.3844934580477326, 'kernel': 'poly', 'degree': 5, 'gamma': 'auto'}. Best is trial 3 with value: 0.661244019138756.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:42,405] Trial 13 finished with value: 0.662200956937799 and parameters: {'C': 0.7487133302446832, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 13 with value: 0.662200956937799.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# /opt/anaconda3/envs/trading/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [I 2024-03-25 18:37:43,978] Trial 14 finished with value: 0.5779904306220096 and parameters: {'C': 2.2684206038604313, 'kernel': 'linear'}. Best is trial 13 with value: 0.662200956937799.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:44,658] Trial 15 finished with value: 0.6593301435406699 and parameters: {'C': 0.013760641748064854, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 13 with value: 0.662200956937799.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# /opt/anaconda3/envs/trading/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [I 2024-03-25 18:37:46,319] Trial 16 finished with value: 0.43923444976076553 and parameters: {'C': 256.8334913026162, 'kernel': 'linear'}. Best is trial 13 with value: 0.662200956937799.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:46,761] Trial 17 finished with value: 0.6593301435406699 and parameters: {'C': 0.006846198817198577, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale'}. Best is trial 13 with value: 0.662200956937799.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# /opt/anaconda3/envs/trading/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [I 2024-03-25 18:37:48,279] Trial 18 finished with value: 0.5607655502392345 and parameters: {'C': 0.474774351266127, 'kernel': 'linear'}. Best is trial 13 with value: 0.662200956937799.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:49,043] Trial 19 finished with value: 0.6593301435406699 and parameters: {'C': 0.04393139342649442, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 13 with value: 0.662200956937799.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:49,864] Trial 20 finished with value: 0.6488038277511962 and parameters: {'C': 4.57838182927836, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 13 with value: 0.662200956937799.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:50,657] Trial 21 finished with value: 0.6593301435406699 and parameters: {'C': 0.35227360079335657, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 13 with value: 0.662200956937799.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:51,441] Trial 22 finished with value: 0.6593301435406699 and parameters: {'C': 0.13599011978427492, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 13 with value: 0.662200956937799.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:52,237] Trial 23 finished with value: 0.662200956937799 and parameters: {'C': 0.7113854282535695, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 13 with value: 0.662200956937799.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/1519862151.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.001, 1000)
# [I 2024-03-25 18:37:53,226] Trial 24 finished with value: 0.6583732057416268 and parameters: {'C': 51.50096367802126, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 13 with value: 0.662200956937799.
# [I 2024-03-25 18:37:53,227] A new study created in memory with name: no-name-e5f175eb-c5bd-4d03-9c14-f50a145aab18
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# Mejores parámetros de SVM: {'C': 0.7487133302446832, 'kernel': 'rbf', 'gamma': 'scale'}
# Precisión del modelo de SVM: 0.662200956937799
# [I 2024-03-25 18:37:53,516] Trial 0 finished with value: 0.5253588516746411 and parameters: {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.3660656803694218, 'subsample': 0.9, 'colsample_bytree': 1.0}. Best is trial 0 with value: 0.5253588516746411.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:37:53,746] Trial 1 finished with value: 0.5550239234449761 and parameters: {'n_estimators': 800, 'max_depth': 3, 'learning_rate': 0.3631125584011118, 'subsample': 1.0, 'colsample_bytree': 0.7}. Best is trial 1 with value: 0.5550239234449761.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:37:53,924] Trial 2 finished with value: 0.5569377990430622 and parameters: {'n_estimators': 600, 'max_depth': 3, 'learning_rate': 0.43352661271324555, 'subsample': 0.8, 'colsample_bytree': 0.7}. Best is trial 2 with value: 0.5569377990430622.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:37:54,209] Trial 3 finished with value: 0.5550239234449761 and parameters: {'n_estimators': 800, 'max_depth': 4, 'learning_rate': 0.34377486303592103, 'subsample': 0.8, 'colsample_bytree': 0.5}. Best is trial 2 with value: 0.5569377990430622.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:37:54,374] Trial 4 finished with value: 0.5559808612440191 and parameters: {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.4455758262654145, 'subsample': 1.0, 'colsample_bytree': 0.6}. Best is trial 2 with value: 0.5569377990430622.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:37:54,561] Trial 5 finished with value: 0.5789473684210527 and parameters: {'n_estimators': 500, 'max_depth': 4, 'learning_rate': 0.030748989611251967, 'subsample': 0.5, 'colsample_bytree': 0.5}. Best is trial 5 with value: 0.5789473684210527.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:37:55,316] Trial 6 finished with value: 0.5502392344497608 and parameters: {'n_estimators': 600, 'max_depth': 10, 'learning_rate': 0.03890267930930435, 'subsample': 0.6, 'colsample_bytree': 0.9}. Best is trial 5 with value: 0.5789473684210527.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:37:55,900] Trial 7 finished with value: 0.569377990430622 and parameters: {'n_estimators': 500, 'max_depth': 10, 'learning_rate': 0.012766863974974767, 'subsample': 0.6, 'colsample_bytree': 0.7}. Best is trial 5 with value: 0.5789473684210527.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:37:56,748] Trial 8 finished with value: 0.5473684210526316 and parameters: {'n_estimators': 1000, 'max_depth': 8, 'learning_rate': 0.08845728615530567, 'subsample': 0.8, 'colsample_bytree': 0.9}. Best is trial 5 with value: 0.5789473684210527.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:37:57,256] Trial 9 finished with value: 0.5435406698564593 and parameters: {'n_estimators': 500, 'max_depth': 10, 'learning_rate': 0.2595113120714957, 'subsample': 0.6, 'colsample_bytree': 1.0}. Best is trial 5 with value: 0.5789473684210527.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:37:57,322] Trial 10 finished with value: 0.6631578947368421 and parameters: {'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.015078398794586863, 'subsample': 0.5, 'colsample_bytree': 0.5}. Best is trial 10 with value: 0.6631578947368421.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:37:57,384] Trial 11 finished with value: 0.6602870813397129 and parameters: {'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.013041414431503487, 'subsample': 0.5, 'colsample_bytree': 0.5}. Best is trial 10 with value: 0.6631578947368421.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:37:57,456] Trial 12 finished with value: 0.6593301435406699 and parameters: {'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.01008929198094812, 'subsample': 0.5, 'colsample_bytree': 0.5}. Best is trial 10 with value: 0.6631578947368421.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
# ...
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:38:55,105] Trial 13 finished with value: 0.5952153110047846 and parameters: {'n_estimators': 500, 'max_depth': 6, 'learning_rate': 0.010294076875731823, 'subsample': 0.5, 'colsample_bytree': 1.0}. Best is trial 12 with value: 0.6038277511961723.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:38:55,405] Trial 14 finished with value: 0.5722488038277512 and parameters: {'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.022187866401014868, 'subsample': 1.0, 'colsample_bytree': 0.9}. Best is trial 12 with value: 0.6038277511961723.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:38:55,479] Trial 15 finished with value: 0.5732057416267943 and parameters: {'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.12164710774237608, 'subsample': 0.7, 'colsample_bytree': 1.0}. Best is trial 12 with value: 0.6038277511961723.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:38:55,937] Trial 16 finished with value: 0.5789473684210527 and parameters: {'n_estimators': 600, 'max_depth': 7, 'learning_rate': 0.015533988146930152, 'subsample': 0.5, 'colsample_bytree': 0.8}. Best is trial 12 with value: 0.6038277511961723.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:38:56,151] Trial 17 finished with value: 0.5808612440191387 and parameters: {'n_estimators': 400, 'max_depth': 5, 'learning_rate': 0.03951718261682636, 'subsample': 0.7, 'colsample_bytree': 0.9}. Best is trial 12 with value: 0.6038277511961723.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:38:56,485] Trial 18 finished with value: 0.5722488038277512 and parameters: {'n_estimators': 600, 'max_depth': 5, 'learning_rate': 0.0329478808939071, 'subsample': 0.5, 'colsample_bytree': 1.0}. Best is trial 12 with value: 0.6038277511961723.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:38:56,745] Trial 19 finished with value: 0.5425837320574163 and parameters: {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.17937066971866059, 'subsample': 0.6, 'colsample_bytree': 0.8}. Best is trial 12 with value: 0.6038277511961723.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:38:56,847] Trial 20 finished with value: 0.6325358851674641 and parameters: {'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.014654819929434446, 'subsample': 0.5, 'colsample_bytree': 1.0}. Best is trial 20 with value: 0.6325358851674641.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:38:56,951] Trial 21 finished with value: 0.6373205741626794 and parameters: {'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.01411233002638551, 'subsample': 0.5, 'colsample_bytree': 1.0}. Best is trial 21 with value: 0.6373205741626794.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:38:57,048] Trial 22 finished with value: 0.6602870813397129 and parameters: {'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.016097786471921612, 'subsample': 0.6, 'colsample_bytree': 0.9}. Best is trial 22 with value: 0.6602870813397129.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:38:57,170] Trial 23 finished with value: 0.6401913875598086 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.015447954675865485, 'subsample': 0.6, 'colsample_bytree': 0.9}. Best is trial 22 with value: 0.6602870813397129.
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.5)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:12: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   subsample = trial.suggest_discrete_uniform('subsample', 0.5, 1.0, 0.1)
# /var/folders/x7/frl5my251vx198wg4w_ndzxh0000gn/T/ipykernel_12196/3346511705.py:13: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   colsample_bytree = trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1.0, 0.1)
# [I 2024-03-25 18:38:57,374] Trial 24 finished with value: 0.5760765550239234 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.029640500581383223, 'subsample': 0.6, 'colsample_bytree': 0.9}. Best is trial 22 with value: 0.6602870813397129.
# Mejores parámetros de XGBoost: {'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.016097786471921612, 'subsample': 0.6, 'colsample_bytree': 0.9}
# Precisión del modelo de XGBoost: 0.6602870813397129

# %%
#Una vez actualizados los parametros optimos .....

# %%
def buy_signals(data):
    buy_signals = pd.DataFrame()
    # Selecciona las características
    X = data.iloc[:, :-1]
    # Selecciona la variable objetivo
    y = data.iloc[:, -1]

    # Crear modelos con los mejores parámetros encontrados para cada algoritmo
    best_logistic_model = LogisticRegression(penalty= 'l2', C= 0.40296273057700516, solver= 'liblinear')
    best_svm_model = SVC(C= 0.9142482404219855, kernel= 'rbf', gamma= 'scale')
    best_xgboost_model = XGBClassifier(n_estimators= 100, max_depth= 7, learning_rate= 0.015749776840105326, subsample= 0.9, colsample_bytree= 0.5)

    # Entrenar los modelos con todo el conjunto de datos original
    best_logistic_model.fit(X, y)
    best_svm_model.fit(X, y)
    best_xgboost_model.fit(X, y)

    # Realizar predicciones en el conjunto de datos original
    predictions_lr = best_logistic_model.predict(X)
    predictions_svm = best_svm_model.predict(X)
    predictions_xgboost = best_xgboost_model.predict(X)
    predictions_xgboost_bool = predictions_xgboost.astype(bool)


    # Agregar las predicciones como nuevas columnas al conjunto de datos original
    buy_signals['predicciones_lr'] = predictions_lr
    buy_signals['predicciones_svm'] = predictions_svm
    buy_signals['predicciones_xgboost'] = predictions_xgboost_bool

    return buy_signals

# %%
def sell_signals(data):
    sell_signals = pd.DataFrame()
    # Selecciona las características
    X = data.iloc[:, :-1]
    # Selecciona la variable objetivo
    y = data.iloc[:, -1]

    # Crear modelos con los mejores parámetros encontrados para cada algoritmo
    best_logistic_model = LogisticRegression(penalty= 'l2', C= 4.03756570068321, solver= 'liblinear')
    best_svm_model = SVC(C= 19.773384392663225, kernel= 'poly', degree= 5, gamma= 'auto')
    best_xgboost_model = XGBClassifier(n_estimators= 300, max_depth= 3, learning_rate= 0.014290645381624112, subsample= 0.6, colsample_bytree= 0.7)

    # Entrenar los modelos con todo el conjunto de datos original
    best_logistic_model.fit(X, y)
    best_svm_model.fit(X, y)
    best_xgboost_model.fit(X, y)

    # Realizar predicciones en el conjunto de datos original
    predictions_lr = best_logistic_model.predict(X)
    predictions_svm = best_svm_model.predict(X)
    predictions_xgboost = best_xgboost_model.predict(X)
    predictions_xgboost_bool = predictions_xgboost.astype(bool)

    # Agregar las predicciones como nuevas columnas al conjunto de datos original
    sell_signals['predicciones_lr'] = predictions_lr
    sell_signals['predicciones_svm'] = predictions_svm
    sell_signals['predicciones_xgboost'] = predictions_xgboost_bool

    return sell_signals

# %%
def backtest(data, buy_signals, sell_signals, stop_loss, take_profit, n_shares):
            history = []
            active_operations = []
            cash = 1_000_000
            com = 1.25 / 100

            for i, row in data.iterrows():
                # close active operation
                active_op_temp = []
                for operation in active_operations:
                    if operation["stop_loss"] > row.Close:
                        cash += (row.Close * operation["n_shares"]) * (1 - com)
                    elif operation["take_profit"] < row.Close:
                        cash += (row.Close * operation["n_shares"]) * (1 - com)
                    else:
                        active_op_temp.append(operation)
                active_operations = active_op_temp

                # check if we have enough cash
                if cash < (row.Close * (1 + com)):
                    asset_vals = sum([operation["n_shares"] * row.Close for operation in active_operations])
                    portfolio_value = cash + asset_vals
                    continue

                # Apply buy signals
                if buy_signals.loc[i].any():
                    active_operations.append({
                        "bought": row.Close,
                        "n_shares": n_shares,
                        "stop_loss": row.Close * stop_loss,
                        "take_profit": row.Close * take_profit
                    })

                    cash -= row.Close * (1 + com) * n_shares

                # Apply sell signals
                if sell_signals.loc[i].any():
                    active_op_temp = []
                    for operation in active_operations:
                        if operation["take_profit"] < row.Close or operation["stop_loss"] > row.Close:
                            cash += (row.Close * operation["n_shares"]) * (1 - com)
                        else:
                            active_op_temp.append(operation)
                    active_operations = active_op_temp

                asset_vals = sum([operation["n_shares"] * row.Close for operation in active_operations])
                portfolio_value = cash + asset_vals

            return portfolio_value

# %%
def optimize(trial, strategy, data):
    portfolio_value = 0

    stop_loss = trial.suggest_float("stop_loss", 0.80, 0.90)
    take_profit = trial.suggest_float("take_profit", 1.01, 1.10)
    n_shares = trial.suggest_int("n_shares", 20, 50)

    strat_params = {}

    buy_signals = pd.DataFrame()
    sell_signals = pd.DataFrame()

    if "logistic" in strategy:
        buy_signals["logistic"] = global_buy_signals_1d["predicciones_lr"]
        sell_signals["logistic"] = global_sell_signals_1d["predicciones_lr"]
        
    if "svm" in strategy:
        buy_signals["svm"] = global_buy_signals_1d["predicciones_svm"]
        sell_signals["svm"] = global_sell_signals_1d["predicciones_svm"]
        
    if "xg" in strategy:
        buy_signals["xg"] = global_buy_signals_1d["predicciones_xgboost"]
        sell_signals["xg"] = global_sell_signals_1d["predicciones_xgboost"]
    
    return backtest(data, buy_signals, sell_signals, stop_loss, take_profit, n_shares)

# %%
def optimize_file(data):
    data = data.drop(data.index[:30])
    data = data.drop(data.index[-30:])
    data.reset_index(drop=True, inplace=True)
    strategies = list(powerset(["logistic", "svm", "xg"]))
    best_strat = None
    best_val = -1
    best_params = None

    for strat in strategies:
        study = optuna.create_study(direction="maximize")
        study.optimize(lambda x: optimize(x, strat, data), n_trials=25)
        value = study.best_value
        if value > best_val:
            best_val = value
            best_strat = strat
            best_params = study.best_params
    print(study.best_value)
    print(best_strat)
    print(best_params)

    return {"file": data,
            "strat": best_strat,
            "value": best_val,
            "params": best_params}

# %%
#Ahora con los datos de prueba

# %%
data_1d_test = pd.read_csv("data/aapl_1d_test.csv")
data_1d_test = data_1d_test.dropna()
dataresult_long_1d_test = file_features(data_1d_test, ds_type="buy")
dataresult_short_1d_test = file_features(data_1d_test, ds_type="sell")
global_buy_signals_1d = buy_signals(dataresult_long_1d_test)
global_sell_signals_1d = sell_signals(dataresult_short_1d_test)
file_1d_test = optimize_file(data_1d_test)
