# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ta

# %%
data = pd.read_csv("aapl_1m_train.csv")
rsi_data = ta.momentum.RSIIndicator(data.Close, window=14)
data["RSI"] = rsi_data.rsi()
data = data.dropna()
data
# Out:
#       Timestamp  Gmtoffset             Datetime        Open        High  \
# 13   1602617400          0  2020-10-13 19:30:00  121.800003  122.050003
# 14   1602682200          0  2020-10-14 13:30:00  121.000000  123.019996
# 15   1602685800          0  2020-10-14 14:30:00  121.690002  122.389999
# 16   1602689400          0  2020-10-14 15:30:00  121.610000  121.730003
# 17   1602693000          0  2020-10-14 16:30:00  120.250000  120.769897
# ..          ...        ...                  ...         ...         ...
# 390  1609432200          0  2020-12-31 16:30:00  132.529998  132.800003
# 391  1609435800          0  2020-12-31 17:30:00  132.619995  132.717605
# 392  1609439400          0  2020-12-31 18:30:00  132.565002  132.889999
# 393  1609443000          0  2020-12-31 19:30:00  132.770004  133.179992
# 394  1609446600          0  2020-12-31 20:30:00  132.794998  133.330001
#
#             Low       Close      Volume        RSI
# 13   121.029998  121.050003  16221506.0  42.205490
# 14   120.040000  121.689903  41414544.0  46.975990
# 15   121.180000  121.599998  17702126.0  46.396536
# 16   119.709999  120.247703  22141570.0  38.669926
# 17   120.000000  120.139999  15375733.0  38.125346
# ..          ...         ...         ...        ...
# 390  131.720001  132.619995  13538948.0  40.278164
# 391  132.310104  132.560806   7474176.0  39.901949
# 392  132.009994  132.764999   9408857.0  41.917511
# 393  132.565994  132.800003  10147999.0  42.274917
# 394  132.449996  132.580001  11777361.0  40.584587
#
# [367 rows x 9 columns]

# %%
def def_trading_strategy(data, n_shares, stop_loss_close, take_profit_close, Umbral):
    cash= 1_000_000
    com = 0.125/100
    history = []
    portfolio_value = []
    active_operations = []
    total_profit_loss = 0

    for i, row in data.iterrows():
        # Close active operation
        active_op_temp = []
        for operation in active_operations:
            if operation["stop_loss"] > row.Close:
                cash += (row.Close * operation["n_shares"]) * (1 - com)
                # Calcular la ganancia o pérdida y actualizar el total
                profit_loss = (row.Close * operation["n_shares"]) * (1 - com) - (operation["bought"] * operation["n_shares"])
                total_profit_loss += profit_loss
                history.append({"timestamp": row.Timestamp, "profit_loss": profit_loss})
            elif operation["take_profit"] < row.Close:
                cash += (row.Close * operation["n_shares"]) * (1 - com)
                # Calcular la ganancia o pérdida y actualizar el total
                profit_loss = (row.Close * operation["n_shares"]) * (1 - com) - (operation["bought"] * operation["n_shares"])
                total_profit_loss += profit_loss
                history.append({"timestamp": row.Timestamp, "profit_loss": profit_loss})
            else:
                active_op_temp.append(operation)
        active_operations = active_op_temp
            
        # ¿Tenemos suficiente efectivo?
        if cash < (row.Close * n_shares * (1 + com)):
            asset_vals = sum([operation["n_shares"] * row.Close for operation in active_operations])
            portfolio_value.append(cash + asset_vals)
            continue
        
        # Analizar la señal larga
        if row.RSI <= Umbral:  # If ceil(Op)
            active_operations.append({
                "timestamp": row.Timestamp,
                "bought": row.Close,
                "n_shares": n_shares,
                "type": "long",
                "stop_loss": row.Close * stop_loss_close,
                "take_profit": row.Close * take_profit_close
            })
            cash -= row.Close * n_shares * (1 + com)
        
        asset_vals = sum([operation["n_shares"] * row.Close for operation in active_operations])
        portfolio_value.append(cash + asset_vals)
    
    return total_profit_loss

# %%
import optuna

def objective(trial):
    # Define los rangos de búsqueda para los parámetros
    n_shares = trial.suggest_int('n_shares', 1, 50)
    stop_loss_close = trial.suggest_uniform('stop_loss_close', 0.80, 1)
    take_profit_close = trial.suggest_uniform('take_profit_close', 1, 1.5)
    Umbral = trial.suggest_uniform('Umbral', 0, 30)

    # Evalúa la función de trading con los parámetros sugeridos
    profit_loss = def_trading_strategy(data, n_shares, stop_loss_close, take_profit_close, Umbral)
    
    return profit_loss  # Devuelve la métrica que se debe minimizar/maximizar

# Crea un estudio Optuna
study = optuna.create_study(direction='maximize')  # 'maximize' si se quiere maximizar la métrica

# Ejecuta la optimización
study.optimize(objective, n_trials=20)  # Puedes ajustar n_trials según tus recursos y tiempo disponible

# Obtiene los mejores parámetros encontrados
best_params = study.best_params
best_profit_loss = study.best_value

print("Mejores parámetros encontrados:")
print(best_params)
print("Rendimiento (Profit/Loss):", best_profit_loss)
# Out:
# [I 2024-02-25 18:53:32,758] A new study created in memory with name: no-name-00a598b3-349f-43a0-8466-9bc288e088bf
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15032\3051087490.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   stop_loss_close = trial.suggest_uniform('stop_loss_close', 0.80, 1)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15032\3051087490.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   take_profit_close = trial.suggest_uniform('take_profit_close', 1, 1.5)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15032\3051087490.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   Umbral = trial.suggest_uniform('Umbral', 0, 30)
# [I 2024-02-25 18:53:32,797] Trial 0 finished with value: 0.0 and parameters: {'n_shares': 18, 'stop_loss_close': 0.9848633111145373, 'take_profit_close': 1.3495571635602168, 'Umbral': 3.4867602666680666}. Best is trial 0 with value: 0.0.
# [I 2024-02-25 18:53:32,901] Trial 1 finished with value: 0.0 and parameters: {'n_shares': 16, 'stop_loss_close': 0.8355448951586781, 'take_profit_close': 1.343494844799723, 'Umbral': 29.084957590754808}. Best is trial 0 with value: 0.0.
# [I 2024-02-25 18:53:32,942] Trial 2 finished with value: 0.0 and parameters: {'n_shares': 49, 'stop_loss_close': 0.9033002366170964, 'take_profit_close': 1.3289585841175169, 'Umbral': 12.184988568925576}. Best is trial 0 with value: 0.0.
# [I 2024-02-25 18:53:32,976] Trial 3 finished with value: 0.0 and parameters: {'n_shares': 1, 'stop_loss_close': 0.972740170504317, 'take_profit_close': 1.4047985131391962, 'Umbral': 11.393190313976095}. Best is trial 0 with value: 0.0.
# [I 2024-02-25 18:53:33,090] Trial 4 finished with value: 0.0 and parameters: {'n_shares': 9, 'stop_loss_close': 0.8491497186118637, 'take_profit_close': 1.2883457875728255, 'Umbral': 29.62826741430365}. Best is trial 0 with value: 0.0.
# [I 2024-02-25 18:53:33,125] Trial 5 finished with value: 0.0 and parameters: {'n_shares': 22, 'stop_loss_close': 0.8789258511665261, 'take_profit_close': 1.1773515255016873, 'Umbral': 10.465582633051245}. Best is trial 0 with value: 0.0.
# [I 2024-02-25 18:53:33,172] Trial 6 finished with value: 0.0 and parameters: {'n_shares': 48, 'stop_loss_close': 0.9557092335467652, 'take_profit_close': 1.2170844234785898, 'Umbral': 21.175535739943744}. Best is trial 0 with value: 0.0.
# [I 2024-02-25 18:53:33,262] Trial 7 finished with value: -623.6953125 and parameters: {'n_shares': 50, 'stop_loss_close': 0.9557917215704741, 'take_profit_close': 1.4333757539789507, 'Umbral': 28.089361905469143}. Best is trial 0 with value: 0.0.
# [I 2024-02-25 18:53:33,299] Trial 8 finished with value: 0.0 and parameters: {'n_shares': 7, 'stop_loss_close': 0.9261940042262398, 'take_profit_close': 1.3721316170378541, 'Umbral': 8.308163748577371}. Best is trial 0 with value: 0.0.
# [I 2024-02-25 18:53:33,386] Trial 9 finished with value: 0.0 and parameters: {'n_shares': 47, 'stop_loss_close': 0.8644493829420326, 'take_profit_close': 1.4436050786021613, 'Umbral': 25.408320989983473}. Best is trial 0 with value: 0.0.
# [I 2024-02-25 18:53:33,454] Trial 10 finished with value: 0.0 and parameters: {'n_shares': 34, 'stop_loss_close': 0.9987981823803412, 'take_profit_close': 1.0784800966161698, 'Umbral': 0.17736464442487376}. Best is trial 0 with value: 0.0.
# [I 2024-02-25 18:53:33,514] Trial 11 finished with value: 0.0 and parameters: {'n_shares': 20, 'stop_loss_close': 0.8019455106213829, 'take_profit_close': 1.2825638865307982, 'Umbral': 1.496466973965111}. Best is trial 0 with value: 0.0.
# [I 2024-02-25 18:53:33,578] Trial 12 finished with value: 279.37930865625026 and parameters: {'n_shares': 15, 'stop_loss_close': 0.8134570988076779, 'take_profit_close': 1.147593505740748, 'Umbral': 19.460785035665307}. Best is trial 12 with value: 279.37930865625026.
# [I 2024-02-25 18:53:33,642] Trial 13 finished with value: 419.5323040000003 and parameters: {'n_shares': 32, 'stop_loss_close': 0.8022244381308145, 'take_profit_close': 1.112661544173555, 'Umbral': 18.727704903151185}. Best is trial 13 with value: 419.5323040000003.
# [I 2024-02-25 18:53:33,702] Trial 14 finished with value: 53.916168160000325 and parameters: {'n_shares': 32, 'stop_loss_close': 0.800801930205625, 'take_profit_close': 1.014968672279729, 'Umbral': 18.847651106125017}. Best is trial 13 with value: 419.5323040000003.
# [I 2024-02-25 18:53:33,765] Trial 15 finished with value: 0.0 and parameters: {'n_shares': 30, 'stop_loss_close': 0.8282447046488456, 'take_profit_close': 1.1364762054072786, 'Umbral': 17.673369111532928}. Best is trial 13 with value: 419.5323040000003.
# [I 2024-02-25 18:53:33,823] Trial 16 finished with value: 842.4205920900013 and parameters: {'n_shares': 36, 'stop_loss_close': 0.8183439448393065, 'take_profit_close': 1.1019806332551436, 'Umbral': 21.44411511529479}. Best is trial 16 with value: 842.4205920900013.
# [I 2024-02-25 18:53:33,889] Trial 17 finished with value: 1146.2144463412506 and parameters: {'n_shares': 39, 'stop_loss_close': 0.8867069041965173, 'take_profit_close': 1.058408670731644, 'Umbral': 23.462185379543303}. Best is trial 17 with value: 1146.2144463412506.
# [I 2024-02-25 18:53:33,954] Trial 18 finished with value: 241.5119041475 and parameters: {'n_shares': 41, 'stop_loss_close': 0.8988374405864311, 'take_profit_close': 1.0115036980588612, 'Umbral': 23.543531282199417}. Best is trial 17 with value: 1146.2144463412506.
# [I 2024-02-25 18:53:34,013] Trial 19 finished with value: 0.0 and parameters: {'n_shares': 40, 'stop_loss_close': 0.8786644945369122, 'take_profit_close': 1.4997783203337836, 'Umbral': 14.903890861125653}. Best is trial 17 with value: 1146.2144463412506.
# Mejores parámetros encontrados:
# {'n_shares': 39, 'stop_loss_close': 0.8867069041965173, 'take_profit_close': 1.058408670731644, 'Umbral': 23.462185379543303}
# Rendimiento (Profit/Loss): 1146.2144463412506

# %%
# Condiciones para comprar y vender
condicion_compra = data["RSI"] <= 30
condicion_venta = data["RSI"] > 70

# Aplicando las condiciones para obtener señales de compra y venta
data['Senal_RSI'] = ''
data.loc[condicion_compra, 'Senal_RSI'] = 'Compra'
data.loc[condicion_venta, 'Senal_RSI'] = 'Venta'
data.to_excel('RSI_BOS.xlsx', index=False)

# %%
data['Senal_RSI'].value_counts()
# Out:
# Senal_RSI
#           330
# Venta      23
# Compra     14
# Name: count, dtype: int64
